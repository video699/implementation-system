# %% [markdown]
# # Measuring the speed and accuracy for all combinations of page detectors, screen detectors, and scene detectors

# %%
from argparse import Namespace
from contextlib import redirect_stderr
from datetime import datetime, timedelta
from itertools import product
from pathlib import Path
from string import Template
import os

import pandas as pd
from IPython.display import display
with open(os.devnull, 'w') as f:
    with redirect_stderr(f):
        import keras
from tqdm import tqdm
from video699.__main__ import PAGE_DETECTOR_NAMES, SCREEN_DETECTOR_NAMES, SCENE_DETECTOR_NAMES, _screen_event_detector

from annotated import VIDEO_FILENAME, DOCUMENT_FILENAME, evaluate_event_detector

COLUMN_NAMES = ['Page detector', 'Screen detector', 'Scene detector']

# %%
# %env CUDA_VISIBLE_DEVICES=
# ^ uncomment to disable GPU in TensorFlow and PyTorch
def duration_and_accuracy(parameters):
    page_detector_name, screen_detector_name, scene_detector_name = parameters
    start_time = datetime.now()
    directory = Path('speed_and_accuracy_outputs')
    directory.mkdir(exist_ok=True)
    output = directory / Path(VIDEO_FILENAME).with_suffix('').name
    output = Path(f'{output}-{page_detector_name}-{screen_detector_name}-{scene_detector_name}')
    accuracy_output = output.with_suffix('.accuracy')
    duration_output = output.with_suffix('.duration')
    accuracy_exists = False
    duration_exists = False
    try:
        with accuracy_output.open('rt') as af:
            accuracy_exists = True
            accuracy = float(af.read())
    except IOError:
        pass
    try:
        with duration_output.open('rt') as df:
            duration_exists = True
            duration = timedelta(seconds=float(df.read()))
    except IOError:
        pass
    if not accuracy_exists or not duration_exists:
        args = Namespace(**{
            'convex_quadrangle_tracker': 'rtree_deque',
            'screen_detector': screen_detector_name,
            'scene_detector': scene_detector_name,
            'page_detector': page_detector_name,
            'institution': 'fimu',
            'room': 'd2',
            'camera': 'default_2004',
            'date': '2019-11-12T00:00:00+01:00',
            'documents': [DOCUMENT_FILENAME],
            'video': VIDEO_FILENAME,
            'quiet': True,
        })
        screen_event_detector = _screen_event_detector(args)
        num_successes, num_trials = evaluate_event_detector(screen_event_detector)
        finish_time = datetime.now()
        duration = finish_time - start_time
        accuracy = 100.0 * num_successes / num_trials
        if not accuracy_exists:
            with accuracy_output.open('wt') as af:
                print(accuracy, file=af)
        if not duration_exists:
            with duration_output.open('wt') as df:
                print(duration.total_seconds(), file=df)
    return (duration, accuracy)

# %%
parameters_list = list(product(PAGE_DETECTOR_NAMES, SCREEN_DETECTOR_NAMES, SCENE_DETECTOR_NAMES))
results = map(duration_and_accuracy, tqdm(parameters_list))
durations, accuracies = zip(*results)
# Out:
# 100%|██████████| 16/16 [3:15:19<00:00, 732.50s/it]

# %%
index = pd.MultiIndex.from_tuples(parameters_list, names=COLUMN_NAMES)
df = pd.Series(map(lambda d: 4546.0 / d.total_seconds(), durations), index=index).unstack(level=0)
df = df[PAGE_DETECTOR_NAMES]
df = df.T[SCREEN_DETECTOR_NAMES].T
df.T.style.set_caption('Speeds').format('{:,.2f}×').background_gradient(cmap='RdYlGn', axis=None)
# Out:
# <style  type="text/css" >
# #T_80aa0650_e48f_11ea_8036_1831bfdd86f9row0_col0{
#             background-color:  #c82227;
#             color:  #f1f1f1;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row0_col1,#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row1_col1,#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row3_col1{
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row0_col2{
#             background-color:  #fb9d59;
#             color:  #000000;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row0_col3{
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row1_col0,#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row3_col0{
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row1_col2{
#             background-color:  #fece7c;
#             color:  #000000;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row1_col3{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row2_col0{
#             background-color:  #ce2827;
#             color:  #f1f1f1;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row2_col1,#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row2_col3{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row2_col2{
#             background-color:  #d02927;
#             color:  #f1f1f1;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row3_col2{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_80aa0650_e48f_11ea_8036_1831bfdd86f9row3_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }</style><table id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9" ><caption>Speeds</caption><thead>    <tr>        <th class="index_name level0" >Screen detector</th>        <th class="col_heading level0 col0" colspan=2>fastai</th>        <th class="col_heading level0 col2" colspan=2>annotated</th>    </tr>    <tr>        <th class="index_name level1" >Scene detector</th>        <th class="col_heading level1 col0" >distance</th>        <th class="col_heading level1 col1" >none</th>        <th class="col_heading level1 col2" >distance</th>        <th class="col_heading level1 col3" >none</th>    </tr>    <tr>        <th class="index_name level0" >Page detector</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9level0_row0" class="row_heading level0 row0" >siamese</th>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row0_col0" class="data row0 col0" >5.14×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row0_col1" class="data row0 col1" >0.85×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row0_col2" class="data row0 col2" >17.84×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row0_col3" class="data row0 col3" >4.05×</td>
#             </tr>
#             <tr>
#                         <th id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9level0_row1" class="row_heading level0 row1" >imagehash</th>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row1_col0" class="data row1 col0" >7.01×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row1_col1" class="data row1 col1" >0.95×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row1_col2" class="data row1 col2" >23.73×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row1_col3" class="data row1 col3" >20.17×</td>
#             </tr>
#             <tr>
#                         <th id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9level0_row2" class="row_heading level0 row2" >vgg16</th>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row2_col0" class="data row2 col0" >5.89×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row2_col1" class="data row2 col1" >0.69×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row2_col2" class="data row2 col2" >6.15×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row2_col3" class="data row2 col3" >0.51×</td>
#             </tr>
#             <tr>
#                         <th id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9level0_row3" class="row_heading level0 row3" >annotated</th>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row3_col0" class="data row3 col0" >7.10×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row3_col1" class="data row3 col1" >0.97×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row3_col2" class="data row3 col2" >25.44×</td>
#                         <td id="T_80aa0650_e48f_11ea_8036_1831bfdd86f9row3_col3" class="data row3 col3" >63.83×</td>
#             </tr>
#     </tbody></table>

# %%
index = pd.MultiIndex.from_tuples(parameters_list, names=COLUMN_NAMES)
df = pd.Series(accuracies, index=index).unstack(level=0)
df = df[PAGE_DETECTOR_NAMES]
df = df.T[SCREEN_DETECTOR_NAMES].T
df.T.style.set_caption('Accuracies').format('{:,.2f}%').background_gradient(cmap='RdYlGn', axis=None)
# Out:
# <style  type="text/css" >
# #T_80aa0651_e48f_11ea_8036_1831bfdd86f9row0_col0{
#             background-color:  #fdaf62;
#             color:  #000000;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row0_col1{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row0_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row0_col3{
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row1_col0{
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row1_col1{
#             background-color:  #c62027;
#             color:  #f1f1f1;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row1_col2{
#             background-color:  #e54e35;
#             color:  #000000;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row1_col3{
#             background-color:  #ea5739;
#             color:  #000000;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row2_col0{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row2_col1{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row2_col2,#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row2_col3{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row3_col0,#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row3_col1,#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row3_col2,#T_80aa0651_e48f_11ea_8036_1831bfdd86f9row3_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }</style><table id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9" ><caption>Accuracies</caption><thead>    <tr>        <th class="index_name level0" >Screen detector</th>        <th class="col_heading level0 col0" colspan=2>fastai</th>        <th class="col_heading level0 col2" colspan=2>annotated</th>    </tr>    <tr>        <th class="index_name level1" >Scene detector</th>        <th class="col_heading level1 col0" >distance</th>        <th class="col_heading level1 col1" >none</th>        <th class="col_heading level1 col2" >distance</th>        <th class="col_heading level1 col3" >none</th>    </tr>    <tr>        <th class="index_name level0" >Page detector</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9level0_row0" class="row_heading level0 row0" >siamese</th>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row0_col0" class="data row0 col0" >32.89%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row0_col1" class="data row0 col1" >38.16%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row0_col2" class="data row0 col2" >3.95%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row0_col3" class="data row0 col3" >6.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9level0_row1" class="row_heading level0 row1" >imagehash</th>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row1_col0" class="data row1 col0" >7.89%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row1_col1" class="data row1 col1" >10.53%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row1_col2" class="data row1 col2" >18.42%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row1_col3" class="data row1 col3" >19.74%</td>
#             </tr>
#             <tr>
#                         <th id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9level0_row2" class="row_heading level0 row2" >vgg16</th>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row2_col0" class="data row2 col0" >65.79%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row2_col1" class="data row2 col1" >69.74%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row2_col2" class="data row2 col2" >73.68%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row2_col3" class="data row2 col3" >73.68%</td>
#             </tr>
#             <tr>
#                         <th id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9level0_row3" class="row_heading level0 row3" >annotated</th>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row3_col0" class="data row3 col0" >100.00%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row3_col1" class="data row3 col1" >100.00%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row3_col2" class="data row3 col2" >100.00%</td>
#                         <td id="T_80aa0651_e48f_11ea_8036_1831bfdd86f9row3_col3" class="data row3 col3" >100.00%</td>
#             </tr>
#     </tbody></table>
