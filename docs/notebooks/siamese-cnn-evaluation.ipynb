# %% [markdown]
# # Evaluating `_KerasSiameseNeuralNetwork`

# %% [markdown]
# Enable logging.

# %%
import logging


logging.basicConfig(format='%(asctime)s : %(message)s', level=logging.INFO)

# %% [markdown]
# Make sure that all annotated page and screen images can fit into the cache.

# %%
from video699.configuration import CONFIGURATION as configuration


configuration['ImageABC']['lru_cache_maxsize'] = '2000'
configuration['ScreenABC']['lru_cache_maxsize'] = '1000'

# %% [markdown]
# Conserve VRAM by instructing TensorFlow to allocate memory on demand.

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session


config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.log_device_placement = True
sess = tf.Session(config=config)
set_session(sess)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Perform leave-one-out cross-validation of the Siamese Neural Network model.

# %%
import numpy as np
from sklearn.model_selection import KFold
from video699.video.annotated import get_videos
from video699.event.siamese import _KerasSiameseNeuralNetwork


annotated_videos = np.array(sorted(get_videos().values(), key=lambda video: video.uri))
kfold = KFold(len(annotated_videos))
training_histories = dict()
for training_set, validation_set in kfold.split(annotated_videos):
    training_videos = set(annotated_videos[training_set])
    validation_video, = annotated_videos[validation_set] 
    model = _KerasSiameseNeuralNetwork(training_videos)
    training_histories[validation_video] = model.training_history
# Out:
# 2019-01-02 11:50:12,431 : Extracting projection screen moments
# 2019-01-02 11:50:16,034 : Extracting document page moments
# 2019-01-02 11:52:58,617 : Done extracting statistical moments
# 2019-01-02 11:52:58,707 : Produced a dataset containing 27480 annotated image pairs
# 2019-01-02 11:52:58,717 : Produced a dataset containing 2049 annotated image pairs
# 2019-01-02 11:52:58,720 : Training a model for 25 epochs
# 2019-01-02 15:06:36,397 : Stored a model in /root/video699/video699/event/siamese/57b21806359e0a084c9ee5dcf4b5ffc5
# 2019-01-02 15:06:36,872 : Extracting projection screen moments
# 2019-01-02 15:06:39,371 : Extracting document page moments
# 2019-01-02 15:06:42,730 : Done extracting statistical moments
# 2019-01-02 15:06:42,855 : Produced a dataset containing 28351 annotated image pairs
# 2019-01-02 15:06:42,865 : Produced a dataset containing 1178 annotated image pairs
# 2019-01-02 15:06:42,867 : Training a model for 25 epochs
# 2019-01-02 18:19:50,330 : Stored a model in /root/video699/video699/event/siamese/2d42fa9fb3665d1686ef24ad31b841d5
# 2019-01-02 18:19:50,651 : Extracting projection screen moments
# 2019-01-02 18:19:51,690 : Extracting document page moments
# 2019-01-02 18:19:53,282 : Done extracting statistical moments
# 2019-01-02 18:19:53,350 : Produced a dataset containing 27229 annotated image pairs
# 2019-01-02 18:19:53,354 : Produced a dataset containing 2300 annotated image pairs
# 2019-01-02 18:19:53,355 : Training a model for 25 epochs
# 2019-01-02 21:27:49,275 : Stored a model in /root/video699/video699/event/siamese/823641feb6be184da750b378cc5c5d5a
# 2019-01-02 21:27:49,598 : Extracting projection screen moments
# 2019-01-02 21:27:50,715 : Extracting document page moments
# 2019-01-02 21:27:52,352 : Done extracting statistical moments
# 2019-01-02 21:27:52,419 : Produced a dataset containing 26279 annotated image pairs
# 2019-01-02 21:27:52,424 : Produced a dataset containing 3250 annotated image pairs
# 2019-01-02 21:27:52,425 : Training a model for 25 epochs
# 2019-01-03 00:32:49,034 : Stored a model in /root/video699/video699/event/siamese/48e0e860f3929759783655ae2db9aecd
# 2019-01-03 00:32:49,511 : Extracting projection screen moments
# 2019-01-03 00:32:50,794 : Extracting document page moments
# 2019-01-03 00:32:52,962 : Done extracting statistical moments
# 2019-01-03 00:32:53,048 : Produced a dataset containing 28905 annotated image pairs
# 2019-01-03 00:32:53,050 : Produced a dataset containing 624 annotated image pairs
# 2019-01-03 00:32:53,051 : Training a model for 25 epochs
# 2019-01-03 03:48:29,405 : Stored a model in /root/video699/video699/event/siamese/4c8f5ff90447e4d52de481e4ac64f9fd
# 2019-01-03 03:48:29,735 : Extracting projection screen moments
# 2019-01-03 03:48:30,790 : Extracting document page moments
# 2019-01-03 03:48:32,397 : Done extracting statistical moments
# 2019-01-03 03:48:32,472 : Produced a dataset containing 27183 annotated image pairs
# 2019-01-03 03:48:32,476 : Produced a dataset containing 2346 annotated image pairs
# 2019-01-03 03:48:32,477 : Training a model for 25 epochs
# 2019-01-03 06:56:39,902 : Stored a model in /root/video699/video699/event/siamese/25ef818139a66d3408dec1bdabe1e5a8
# 2019-01-03 06:56:40,356 : Extracting projection screen moments
# 2019-01-03 06:56:41,450 : Extracting document page moments
# 2019-01-03 06:56:43,059 : Done extracting statistical moments
# 2019-01-03 06:56:43,135 : Produced a dataset containing 28137 annotated image pairs
# 2019-01-03 06:56:43,140 : Produced a dataset containing 2784 annotated image pairs
# 2019-01-03 06:56:43,141 : Training a model for 25 epochs
# 2019-01-03 10:12:23,124 : Rebuilding model with insufficient training accuracy of 0.6651669778129704 (< 0.95)
# 2019-01-03 10:12:23,909 : Training a model for 25 epochs
# 2019-01-03 13:27:44,567 : Stored a model in /root/video699/video699/event/siamese/c7a1fa21618275a8101886f4d173ad10
# 2019-01-03 13:27:44,900 : Extracting projection screen moments
# 2019-01-03 13:27:46,053 : Extracting document page moments
# 2019-01-03 13:27:47,599 : Done extracting statistical moments
# 2019-01-03 13:27:47,686 : Produced a dataset containing 29529 annotated image pairs
# 2019-01-03 13:27:47,690 : Produced a dataset containing 2348 annotated image pairs
# 2019-01-03 13:27:47,691 : Training a model for 25 epochs
# 2019-01-03 16:51:33,308 : Stored a model in /root/video699/video699/event/siamese/e875e6b194b05b2ca7937faf1453de9e
# 2019-01-03 16:51:33,770 : Extracting projection screen moments
# 2019-01-03 16:51:34,909 : Extracting document page moments
# 2019-01-03 16:51:36,683 : Done extracting statistical moments
# 2019-01-03 16:51:36,762 : Produced a dataset containing 26756 annotated image pairs
# 2019-01-03 16:51:36,770 : Produced a dataset containing 5546 annotated image pairs
# 2019-01-03 16:51:36,771 : Training a model for 25 epochs
# 2019-01-03 20:06:00,426 : Rebuilding model with insufficient training accuracy of 0.75033713265026 (< 0.95)
# 2019-01-03 20:06:01,541 : Training a model for 25 epochs
# 2019-01-03 23:20:02,223 : Rebuilding model with insufficient training accuracy of 0.6956887099018081 (< 0.95)
# 2019-01-03 23:20:02,267 : Training a model for 25 epochs
# 2019-01-04 02:33:25,712 : Rebuilding model with insufficient training accuracy of 0.7493041473946098 (< 0.95)
# 2019-01-04 02:33:25,857 : Training a model for 25 epochs
# 2019-01-04 05:46:08,040 : Rebuilding model with insufficient training accuracy of 0.753501747769792 (< 0.95)
# 2019-01-04 05:46:08,078 : Training a model for 25 epochs
# 2019-01-04 08:58:28,503 : Rebuilding model with insufficient training accuracy of 0.7319872690157819 (< 0.95)
# 2019-01-04 08:58:28,543 : Training a model for 25 epochs
# 2019-01-04 12:11:20,697 : Rebuilding model with insufficient training accuracy of 0.751184685308626 (< 0.95)
# 2019-01-04 12:11:20,736 : Training a model for 25 epochs
# 2019-01-04 15:24:09,777 : Rebuilding model with insufficient training accuracy of 0.7380771911684254 (< 0.95)
# 2019-01-04 15:24:09,844 : Training a model for 25 epochs
# 2019-01-04 18:37:05,811 : Stored a model in /root/video699/video699/event/siamese/4292aef58856792e50fc52473ffc65b8
# 2019-01-04 18:37:06,440 : Extracting projection screen moments
# 2019-01-04 18:37:07,557 : Extracting document page moments
# 2019-01-04 18:37:09,163 : Done extracting statistical moments
# 2019-01-04 18:37:09,233 : Produced a dataset containing 24597 annotated image pairs
# 2019-01-04 18:37:09,241 : Produced a dataset containing 4932 annotated image pairs
# 2019-01-04 18:37:09,242 : Training a model for 25 epochs
# 2019-01-04 21:35:02,782 : Stored a model in /root/video699/video699/event/siamese/f141bb82ee5e294c6345bfa6bdc0202b
# 2019-01-04 21:35:03,251 : Extracting projection screen moments
# 2019-01-04 21:35:04,892 : Extracting document page moments
# 2019-01-04 21:35:07,530 : Done extracting statistical moments
# 2019-01-04 21:35:07,623 : Produced a dataset containing 28679 annotated image pairs
# 2019-01-04 21:35:07,626 : Produced a dataset containing 850 annotated image pairs
# 2019-01-04 21:35:07,627 : Training a model for 25 epochs
# 2019-01-05 00:52:19,034 : Stored a model in /root/video699/video699/event/siamese/897b9d1129c48f520405abb19325e668
# 2019-01-05 00:52:19,938 : Extracting projection screen moments
# 2019-01-05 00:52:21,769 : Extracting document page moments
# 2019-01-05 00:52:24,915 : Done extracting statistical moments
# 2019-01-05 00:52:25,005 : Produced a dataset containing 28655 annotated image pairs
# 2019-01-05 00:52:25,008 : Produced a dataset containing 874 annotated image pairs
# 2019-01-05 00:52:25,009 : Training a model for 25 epochs
# 2019-01-05 04:08:37,499 : Stored a model in /root/video699/video699/event/siamese/4bbdc3ef9d12054dda20d93d9e3e7cf5
# 2019-01-05 04:08:38,100 : Extracting projection screen moments
# 2019-01-05 04:08:40,144 : Extracting document page moments
# 2019-01-05 04:08:43,020 : Done extracting statistical moments
# 2019-01-05 04:08:43,116 : Produced a dataset containing 27241 annotated image pairs
# 2019-01-05 04:08:43,121 : Produced a dataset containing 2288 annotated image pairs
# 2019-01-05 04:08:43,121 : Training a model for 25 epochs
# 2019-01-05 07:17:29,872 : Rebuilding model with insufficient training accuracy of 0.7190324110845817 (< 0.95)
# 2019-01-05 07:17:31,628 : Training a model for 25 epochs
# 2019-01-05 10:25:54,076 : Stored a model in /root/video699/video699/event/siamese/ba5d26614b3468f66b774ba59c59c3d5
# 2019-01-05 10:25:54,556 : Extracting projection screen moments
# 2019-01-05 10:25:55,804 : Extracting document page moments
# 2019-01-05 10:25:57,580 : Done extracting statistical moments
# 2019-01-05 10:25:57,970 : Produced a dataset containing 28213 annotated image pairs
# 2019-01-05 10:25:57,975 : Produced a dataset containing 1316 annotated image pairs
# 2019-01-05 10:25:57,976 : Training a model for 25 epochs
# 2019-01-05 13:39:02,894 : Rebuilding model with insufficient training accuracy of 0.7334162643771438 (< 0.95)
# 2019-01-05 13:39:04,778 : Training a model for 25 epochs
# 2019-01-05 16:51:50,078 : Stored a model in /root/video699/video699/event/siamese/c9bfc12f821b554519fc5bf7bc36112c
# 2019-01-05 22:53:53,473 : Extracting projection screen moments
# 2019-01-05 22:53:55,675 : Extracting document page moments
# 2019-01-05 22:57:14,277 : Done extracting statistical moments
# 2019-01-05 22:57:14,352 : Produced a dataset containing 28792 annotated image pairs
# 2019-01-05 22:57:14,355 : Produced a dataset containing 1474 annotated image pairs
# 2019-01-05 22:57:14,356 : Training a model for 25 epochs
# 2019-01-06 02:14:19,318 : Stored a model in /root/video699/video699/event/siamese/8f6aad3533e1be2d285c6c814ec62a02
# 2019-01-06 02:14:19,706 : Extracting projection screen moments
# 2019-01-06 02:14:20,820 : Extracting document page moments
# 2019-01-06 02:14:22,492 : Done extracting statistical moments
# 2019-01-06 02:14:22,894 : Produced a dataset containing 28246 annotated image pairs
# 2019-01-06 02:14:22,896 : Produced a dataset containing 1283 annotated image pairs
# 2019-01-06 02:14:22,897 : Training a model for 25 epochs
# 2019-01-06 05:27:34,514 : Rebuilding model with insufficient training accuracy of 0.6173353567112778 (< 0.95)
# 2019-01-06 05:27:35,657 : Training a model for 25 epochs
# 2019-01-06 08:40:21,963 : Stored a model in /root/video699/video699/event/siamese/404f996ac6e830f57d3728ac49c1d8b5
# 2019-01-06 08:40:22,359 : Extracting projection screen moments
# 2019-01-06 08:40:23,497 : Extracting document page moments
# 2019-01-06 08:40:25,106 : Done extracting statistical moments
# 2019-01-06 08:40:25,182 : Produced a dataset containing 28192 annotated image pairs
# 2019-01-06 08:40:25,185 : Produced a dataset containing 2093 annotated image pairs
# 2019-01-06 08:40:25,186 : Training a model for 25 epochs
# 2019-01-06 11:55:02,394 : Rebuilding model with insufficient training accuracy of 0.7031336606783575 (< 0.95)
# 2019-01-06 11:55:03,382 : Training a model for 25 epochs
# 2019-01-06 15:09:29,235 : Stored a model in /root/video699/video699/event/siamese/71fe8f537939047b95929898358eda0b

# %% [markdown]
# Estimate and plot the mean of the training and the validation accuracy using [bootstrapping][].
#
#  [bootstrapping]: https://ocw.mit.edu/courses/mathematics/18-05-introduction-to-probability-and-statistics-spring-2014/readings/MIT18_05S14_Reading24.pdf (Bootstrap confidence intervals)

# %%
from video699.configuration import get_configuration


configuration = get_configuration()['KerasSiamesePageDetector']
num_training_epochs = configuration.getint('num_training_epochs')
alpha = 0.05
training_color = 'blue'
validation_color = 'red'
base_linewidth = 0.1
bound_linewidth = 1
mean_linewidth = 3
interval_alpha = 0.2

# %% [markdown]
# Plot the mean of the training and the validation accuracy.

# %%
# %matplotlib inline
import bootstrapped.bootstrap as bs
import bootstrapped.stats_functions as bs_stats
import matplotlib.pyplot as plt


epochs = range(1, num_training_epochs + 1)

training_means = [
    bs.bootstrap(np.array([
        training_history['weighted_acc'][index] for training_history in training_histories.values()
    ]), stat_func=bs_stats.mean, alpha=alpha)
    for index in range(num_training_epochs)
]
training_means_pointwise = tuple(map(lambda x: x.value, training_means))
training_means_lower = tuple(map(lambda x: x.lower_bound, training_means))
training_means_upper = tuple(map(lambda x: x.upper_bound, training_means))

validation_means = [
    bs.bootstrap(np.array([
        training_history['val_weighted_acc'][index] for training_history in training_histories.values()
    ]), stat_func=bs_stats.mean, alpha=alpha)
    for index in range(num_training_epochs)
]
validation_means_pointwise = tuple(map(lambda x: x.value, validation_means))
validation_means_lower = tuple(map(lambda x: x.lower_bound, validation_means))
validation_means_upper = tuple(map(lambda x: x.upper_bound, validation_means))

plt.figure(1, figsize=(10, 3))

plt.plot(epochs, training_means_lower, color=training_color, linewidth=bound_linewidth)
plt.plot(epochs, training_means_upper, color=training_color, linewidth=bound_linewidth)
plt.fill_between(epochs, training_means_lower, training_means_upper, color=training_color, alpha=interval_alpha)

plt.plot(epochs, validation_means_lower, color=validation_color, linewidth=bound_linewidth)
plt.plot(epochs, validation_means_upper, color=validation_color, linewidth=bound_linewidth)
plt.fill_between(epochs, validation_means_lower, validation_means_upper, color=validation_color, alpha=interval_alpha)

for training_history in training_histories.values():
    plt.plot(epochs, training_history['weighted_acc'], color=training_color, linewidth=base_linewidth)
    plt.plot(epochs, training_history['val_weighted_acc'], color=validation_color, linewidth=base_linewidth)

plt.plot(epochs, training_means_pointwise, marker='o', color=training_color, linewidth=mean_linewidth, label='training mean')
plt.plot(epochs, validation_means_pointwise, marker='^', color=validation_color, linewidth=mean_linewidth, label='validation mean')

plt.legend(loc='lower right')
plt.xlabel('epoch')
plt.xlim(1, num_training_epochs)
plt.ylabel('weighted accuracy')
plt.ylim(0.5, 1)
plt.grid()
plt.savefig('figures/siamese-21.pdf')
plt.show()

# %% [markdown]
# Show the outlier, and the best-performing validation video.

# %%
sorted_videos = sorted(get_videos().values(), key=lambda video: max(training_histories[video]['val_weighted_acc']))

# %%
video = sorted_videos[0]
epoch, validation_accuracy = max(enumerate(training_histories[video]['val_weighted_acc']), key=lambda x: x[1])
print('{},\tvalidation weighted accuracy: {:.2f} (epoch {})'.format(video.filename, validation_accuracy, epoch))

plt.figure(figsize=(20, 12))
for index, frame in zip(range(3), video):
    plt.subplot(1, 3, index + 1).imshow(frame.image)
plt.savefig('figures/siamese-22.pdf')
# Out:
# PB069-D2-20140305.mp4,	validation weighted accuracy: 0.75 (epoch 11)

# %%
video = sorted_videos[-1]
epoch, validation_accuracy = max(enumerate(training_histories[video]['val_weighted_acc']), key=lambda x: x[1])
print('{},\tvalidation weighted accuracy: {:.2f} (epoch {})'.format(video.filename, validation_accuracy, epoch))

plt.figure(figsize=(20, 12))
for index, frame in zip(range(3), video):
    plt.subplot(1, 3, index + 1).imshow(frame.image)
plt.savefig('figures/siamese-23.pdf')
# Out:
# PA152-D3-20110331.avi,	validation weighted accuracy: 1.00 (epoch 22)
